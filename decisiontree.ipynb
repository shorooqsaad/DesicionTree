# %%
import pandas as pd
import numpy as np

# %%
#Reading imported file in the Notebook
#Showing the first 5 col.
data = '../input/heartdt/heart(1).csv'

df = pd.read_csv(data)
df.head()

df2 = pd.DataFrame({'age': [30, 35, 40, 45, 50, 55, 60, 65, 70,
                           75, 80]})
print(df2)

df3 = pd.DataFrame({'trestbps': [90,100,110,120,130,140,150,160,170,180,190,200]})
print(df3)

df4 = pd.DataFrame({'chol': [130, 170, 210, 270, 300, 360, 400, 450, 500,
                           560]})
print(df4)

df5 = pd.DataFrame({'thalach': [75, 85, 95, 110,120,130,140, 150, 160, 170, 180, 190,
                           200]})
print(df5)

df6 = pd.DataFrame({'oldpeak': [0,1,2,3,4,5,6]})
print(df6)

# %%
inputs = df.drop('target',axis='columns')
target = df['target']

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs, target)

# %%
model.score(inputs,target)

# %% [markdown]
# Will the model predict the right desicion?

# %%
print(model.predict([[60,1,0,125,258,0,0,141,1,2.8,1,1,3]]))
